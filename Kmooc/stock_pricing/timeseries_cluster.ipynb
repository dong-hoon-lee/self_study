# %% [markdown]
# ### Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import plotly
from tqdm import tqdm

from sklearn.cluster import KMeans
from sklearn.preprocessing import Normalizer

# %%
with open('./data/stockcodes.json', 'r', encoding='utf-8') as f:
    codes = json.load(f)

df = pd.read_csv('./data/stockcandles_day.csv', dtype={'code':str})

# %%
def load_data():
    with open('./data/stockcodes.json', 'r', encoding='utf-8') as f:
        codes = json.load(f)

    df = pd.read_csv('./data/stockcandles_day.csv', dtype={'code':str})

    return codes, df

# %%
codes, df = load_data()

# %%
codes
# Out:
# [{'name': 'HSD엔진', 'code': '082740'},
#  {'name': 'KG케미칼', 'code': '001390'},
#  {'name': 'LG이노텍', 'code': '011070'},
#  {'name': 'SH에너지화학', 'code': '002360'},
#  {'name': 'SK네트웍스', 'code': '001740'},
#  {'name': 'STX중공업', 'code': '071970'},
#  {'name': 'WISCOM', 'code': '024070'},
#  {'name': '갤럭시아에스엠', 'code': '011420'},
#  {'name': '경동도시가스', 'code': '267290'},
#  {'name': '고려제강', 'code': '002240'},
#  {'name': '상상인증권', 'code': '001290'},
#  {'name': '극동유화', 'code': '014530'},
#  {'name': '금호에이치티', 'code': '214330'},
#  {'name': '까뮤이앤씨', 'code': '013700'},
#  {'name': '노루페인트', 'code': '090350'},
#  {'name': '녹십자홀딩스', 'code': '005250'},
#  {'name': '삼일씨엔에스', 'code': '004440'},
#  {'name': '대영포장', 'code': '014160'},
#  {'name': '대웅', 'code': '003090'},
#  {'name': '대원제약', 'code': '003220'},
#  {'name': '대유에이텍', 'code': '002880'},
#  {'name': '케이비아이동국실업', 'code': '001620'},
#  {'name': '동남합성', 'code': '023450'},
#  {'name': '동방', 'code': '004140'},
#  {'name': '동아쏘시오홀딩스', 'code': '000640'},
#  {'name': '동양', 'code': '001520'},
#  {'name': '롯데손해보험', 'code': '000400'},
#  {'name': '롯데하이마트', 'code': '071840'},
#  {'name': '모두투어리츠', 'code': '204210'},
#  {'name': '무림페이퍼', 'code': '009200'},
#  {'name': '무학', 'code': '033920'},
#  {'name': '미래에셋생명', 'code': '085620'},
#  {'name': '삼성SDI', 'code': '006400'},
#  {'name': '삼성바이오로직스', 'code': '207940'},
#  {'name': '삼성출판사', 'code': '068290'},
#  {'name': '삼성카드', 'code': '029780'},
#  {'name': '삼성화재해상보험', 'code': '000810'},
#  {'name': '삼영전자공업', 'code': '005680'},
#  {'name': '삼영화학공업', 'code': '003720'},
#  {'name': '삼진제약', 'code': '005500'},
#  {'name': '선도전기', 'code': '007610'},
#  {'name': '선진', 'code': '136490'},
#  {'name': '세원이앤씨', 'code': '091090'},
#  {'name': '세이브존I&C', 'code': '067830'},
#  {'name': '신풍제약', 'code': '019170'},
#  {'name': '신한지주', 'code': '055550'},
#  {'name': '아시아나항공', 'code': '020560'},
#  {'name': '아이에스동서', 'code': '010780'},
#  {'name': '영화금속', 'code': '012280'},
#  {'name': '오리온', 'code': '271560'},
#  {'name': '우진', 'code': '105840'},
#  {'name': '웅진', 'code': '016880'},
#  {'name': '원림', 'code': '005820'},
#  {'name': '윌비스', 'code': '008600'},
#  {'name': '유나이티드', 'code': '033270'},
#  {'name': '유니온머티리얼', 'code': '047400'},
#  {'name': '이리츠코크렙', 'code': '088260'},
#  {'name': '인지컨트롤스', 'code': '023800'},
#  {'name': '일동제약', 'code': '249420'},
#  {'name': '제이에스코퍼레이션', 'code': '194370'},
#  {'name': '제이준코스메틱', 'code': '025620'},
#  {'name': '제일약품', 'code': '271980'},
#  {'name': '제일연마', 'code': '001560'},
#  {'name': '제일파마홀딩스', 'code': '002620'},
#  {'name': '조일알미늄', 'code': '018470'},
#  {'name': '조흥', 'code': '002600'},
#  {'name': '진도', 'code': '088790'},
#  {'name': '케이씨', 'code': '029460'},
#  {'name': '코리아써키트', 'code': '007810'},
#  {'name': '코스맥스', 'code': '192820'},
#  {'name': '코오롱플라스틱', 'code': '138490'},
#  {'name': '코웨이', 'code': '021240'},
#  {'name': '키다리스튜디오', 'code': '020120'},
#  {'name': '태광산업', 'code': '003240'},
#  {'name': '태양금속공업', 'code': '004100'},
#  {'name': '한국주철관공업', 'code': '000970'},
#  {'name': '한국철강', 'code': '104700'},
#  {'name': '한국토지신탁', 'code': '034830'},
#  {'name': '한국패러랠', 'code': '168490'},
#  {'name': '한미약품', 'code': '128940'},
#  {'name': '한솔테크닉스', 'code': '004710'},
#  {'name': '한일철강', 'code': '002220'},
#  {'name': '한진', 'code': '002320'},
#  {'name': '한창제지', 'code': '009460'},
#  {'name': '현대건설기계', 'code': '267270'},
#  {'name': '현대비앤지스틸', 'code': '004560'},
#  {'name': '한국조선해양', 'code': '009540'},
#  {'name': '호전실업', 'code': '111110'},
#  {'name': '호텔신라', 'code': '008770'},
#  {'name': 'BGF', 'code': '027410'},
#  {'name': 'CS홀딩스', 'code': '000590'},
#  {'name': 'DRB동일', 'code': '004840'},
#  {'name': 'GKL', 'code': '114090'},
#  {'name': 'GS건설', 'code': '006360'},
#  {'name': 'GS글로벌', 'code': '001250'},
#  {'name': 'JW중외제약', 'code': '001060'},
#  {'name': 'KB금융', 'code': '105560'},
#  {'name': 'KR모터스', 'code': '000040'},
#  {'name': 'LG디스플레이', 'code': '034220'},
#  {'name': 'OCI', 'code': '010060'},
#  {'name': 'SNT모티브', 'code': '064960'},
#  {'name': 'SG글로벌', 'code': '001380'},
#  {'name': 'SK', 'code': '034730'},
#  {'name': 'SKC', 'code': '011790'},
#  {'name': '경동인베스트', 'code': '012320'},
#  {'name': '경보제약', 'code': '214390'},
#  {'name': '금강공업', 'code': '014280'},
#  {'name': '깨끗한나라', 'code': '004540'},
#  {'name': '남성', 'code': '004270'},
#  {'name': '넷마블', 'code': '251270'},
#  {'name': '대구백화점', 'code': '006370'},
#  {'name': '대림통상', 'code': '006570'},
#  {'name': '대양금속', 'code': '009190'},
#  {'name': '대우건설', 'code': '047040'},
#  {'name': '대유플러스', 'code': '000300'},
#  {'name': '대한방직', 'code': '001070'},
#  {'name': '대한전선', 'code': '001440'},
#  {'name': '대한제강', 'code': '084010'},
#  {'name': '대현', 'code': '016090'},
#  {'name': '동방아그로', 'code': '007590'},
#  {'name': '동성케미컬', 'code': '102260'},
#  {'name': '동양생명', 'code': '082640'},
#  {'name': '동원금속', 'code': '018500'},
#  {'name': '현대두산인프라코어', 'code': '042670'},
#  {'name': '두올', 'code': '016740'},
#  {'name': '디씨엠', 'code': '024090'},
#  {'name': '롯데케미칼', 'code': '011170'},
#  {'name': '미원에스씨', 'code': '268280'},
#  {'name': '미원홀딩스', 'code': '107590'},
#  {'name': '백산', 'code': '035150'},
#  {'name': '범양건영', 'code': '002410'},
#  {'name': '보락', 'code': '002760'},
#  {'name': '보령', 'code': '003850'},
#  {'name': '보해양조', 'code': '000890'},
#  {'name': '빙그레', 'code': '005180'},
#  {'name': '사조대림', 'code': '003960'},
#  {'name': '사조동아원', 'code': '008040'},
#  {'name': '사조씨푸드', 'code': '014710'},
#  {'name': '삼양사', 'code': '145990'},
#  {'name': '삼양식품', 'code': '003230'},
#  {'name': '삼원강재', 'code': '023000'},
#  {'name': 'DL건설', 'code': '001880'},
#  {'name': '서원', 'code': '021050'},
#  {'name': '세방전지', 'code': '004490'},
#  {'name': '송원산업', 'code': '004430'},
#  {'name': '신영와코루', 'code': '005800'},
#  {'name': '써니전자', 'code': '004770'},
#  {'name': '아모레퍼시픽그룹', 'code': '002790'},
#  {'name': '아이마켓코리아', 'code': '122900'},
#  {'name': '아이에이치큐', 'code': '003560'},
#  {'name': '엔씨소프트', 'code': '036570'},
#  {'name': '엔케이', 'code': '085310'},
#  {'name': '영보화학', 'code': '014440'},
#  {'name': '영원무역', 'code': '111770'},
#  {'name': '영진약품', 'code': '003520'},
#  {'name': '영풍', 'code': '000670'},
#  {'name': '유한양행', 'code': '000100'},
#  {'name': '이수화학', 'code': '005950'},
#  {'name': '이스타코', 'code': '015020'},
#  {'name': '인디에프', 'code': '014990'},
#  {'name': '일정실업', 'code': '008500'},
#  {'name': '조선선재', 'code': '120030'},
#  {'name': '종근당', 'code': '185750'},
#  {'name': '지역난방공사', 'code': '071320'},
#  {'name': '진에어', 'code': '272450'},
#  {'name': '진원생명과학', 'code': '011000'},
#  {'name': '케이티', 'code': '030200'},
#  {'name': '코스모화학', 'code': '005420'},
#  {'name': '코아스', 'code': '071950'},
#  {'name': '큐로', 'code': '015590'},
#  {'name': '태경케미컬', 'code': '006890'},
#  {'name': '토니모리', 'code': '214420'},
#  {'name': '하이트론씨스템즈', 'code': '019490'},
#  {'name': '하이트진로', 'code': '000080'},
#  {'name': '한국가스공사', 'code': '036460'},
#  {'name': '한국금융지주', 'code': '071050'},
#  {'name': '한국카본', 'code': '017960'},
#  {'name': '한국콜마', 'code': '161890'},
#  {'name': '한국항공우주', 'code': '047810'},
#  {'name': '한독', 'code': '002390'},
#  {'name': '한전KPS', 'code': '051600'},
#  {'name': 'HJ중공업', 'code': '097230'},
#  {'name': '해태제과식품', 'code': '101530'},
#  {'name': 'HMM', 'code': '011200'},
#  {'name': '한일현대시멘트', 'code': '006390'},
#  {'name': '현대퓨처넷', 'code': '126560'},
#  {'name': '현대해상', 'code': '001450'},
#  {'name': '화승엔터프라이즈', 'code': '241590'},
#  {'name': '화승인더스트리', 'code': '006060'},
#  {'name': '화천기공', 'code': '000850'},
#  {'name': '환인제약', 'code': '016580'},
#  {'name': '효성티앤씨', 'code': '298020'},
#  {'name': '후성', 'code': '093370'},
#  {'name': 'CJ CGV', 'code': '079160'},
#  {'name': 'CJ대한통운', 'code': '000120'},
#  {'name': 'LG헬로비전', 'code': '037560'},
#  {'name': 'HDC현대산업개발', 'code': '294870'},
#  {'name': 'KPX케미칼', 'code': '025000'},
#  {'name': 'MH에탄올', 'code': '023150'},
#  {'name': '엔에이치엔', 'code': '181710'},
#  {'name': 'S-Oil', 'code': '010950'},
#  {'name': 'SBS', 'code': '034120'},
#  {'name': 'SK텔레콤', 'code': '017670'},
#  {'name': 'YG PLUS', 'code': '037270'},
#  {'name': '경방', 'code': '000050'},
#  {'name': '국동', 'code': '005320'},
#  {'name': '국제약품', 'code': '002720'},
#  {'name': '금양', 'code': '001570'},
#  {'name': '기아', 'code': '000270'},
#  {'name': '남광토건', 'code': '001260'},
#  {'name': '비비안', 'code': '002070'},
#  {'name': '넥센타이어', 'code': '002350'},
#  {'name': '농심홀딩스', 'code': '072710'},
#  {'name': '다스코', 'code': '058730'},
#  {'name': '대상홀딩스', 'code': '084690'},
#  {'name': '대웅제약', 'code': '069620'},
#  {'name': '대한유화', 'code': '006650'},
#  {'name': '덕성', 'code': '004830'},
#  {'name': '동서', 'code': '026960'},
#  {'name': '동아지질', 'code': '028100'},
#  {'name': '동원산업', 'code': '006040'},
#  {'name': '디아이', 'code': '003160'},
#  {'name': '디티알오토모티브', 'code': '007340'},
#  {'name': '스틱인베스트먼트', 'code': '026890'},
#  {'name': '마니커', 'code': '027740'},
#  {'name': '맥쿼리인프라', 'code': '088980'},
#  {'name': '메리츠증권', 'code': '008560'},
#  {'name': '명문제약', 'code': '017180'},
#  {'name': '모토닉', 'code': '009680'},
#  {'name': '미원화학', 'code': '134380'},
#  {'name': '베트남개발1', 'code': '096300'},
#  {'name': '삼성에스디에스', 'code': '018260'},
#  {'name': '삼성중공업', 'code': '010140'},
#  {'name': '삼성증권', 'code': '016360'},
#  {'name': '삼양통상', 'code': '002170'},
#  {'name': '삼영무역', 'code': '002810'},
#  {'name': '삼정펄프', 'code': '009770'},
#  {'name': '삼호개발', 'code': '010960'},
#  {'name': '삼화페인트공업', 'code': '000390'},
#  {'name': '샘표식품', 'code': '248170'},
#  {'name': '성보화학', 'code': '003080'},
#  {'name': '시디즈', 'code': '134790'},
#  {'name': '신성이엔지', 'code': '011930'},
#  {'name': '신영증권', 'code': '001720'},
#  {'name': 'SHD', 'code': '001770'},
#  {'name': '쌍방울', 'code': '102280'},
#  {'name': '예스코홀딩스', 'code': '015360'},
#  {'name': '유니온', 'code': '000910'},
#  {'name': '유니켐', 'code': '011330'},
#  {'name': '유진증권', 'code': '001200'},
#  {'name': '유화증권', 'code': '003460'},
#  {'name': '이월드', 'code': '084680'},
#  {'name': '일진디스플', 'code': '020760'},
#  {'name': '종근당바이오', 'code': '063160'},
#  {'name': '진양폴리우레탄', 'code': '010640'},
#  {'name': '진양화학', 'code': '051630'},
#  {'name': '진흥기업', 'code': '002780'},
#  {'name': '코스맥스비티아이', 'code': '044820'},
#  {'name': '코스모신소재', 'code': '005070'},
#  {'name': '코오롱', 'code': '002020'},
#  {'name': '콤텍시스템', 'code': '031820'},
#  {'name': '태평양물산', 'code': '007980'},
#  {'name': '텔코웨어', 'code': '078000'},
#  {'name': '티웨이홀딩스', 'code': '004870'},
#  {'name': '파미셀', 'code': '005690'},
#  {'name': '퍼시스', 'code': '016800'},
#  {'name': '풍산홀딩스', 'code': '005810'},
#  {'name': '하이스틸', 'code': '071090'},
#  {'name': '한국공항', 'code': '005430'},
#  {'name': '한국석유공업', 'code': '004090'},
#  {'name': '한국수출포장공업', 'code': '002200'},
#  {'name': '한국자산신탁', 'code': '123890'},
#  {'name': '한라홀딩스', 'code': '060980'},
#  {'name': '한섬', 'code': '020000'},
#  {'name': '한솔홀딩스', 'code': '004150'},
#  {'name': '한신기계공업', 'code': '011700'},
#  {'name': '한화에어로스페이스', 'code': '012450'},
#  {'name': '현대그린푸드', 'code': '005440'},
#  {'name': '효성 ITX', 'code': '094280'},
#  {'name': '휴니드테크놀러지스', 'code': '005870'},
#  {'name': 'AJ네트웍스', 'code': '095570'},
#  {'name': 'SK렌터카', 'code': '068400'},
#  {'name': 'DB하이텍', 'code': '000990'},
#  {'name': 'DSR제강', 'code': '069730'},
#  {'name': 'JW홀딩스', 'code': '096760'},
#  {'name': 'KSS해운', 'code': '044450'},
#  {'name': 'LF', 'code': '093050'},
#  {'name': 'LX하우시스', 'code': '108670'},
#  {'name': 'LIG넥스원', 'code': '079550'},
#  {'name': 'LS', 'code': '006260'},
#  {'name': 'LS네트웍스', 'code': '000680'},
#  {'name': 'NAVER', 'code': '035420'},
#  {'name': 'NH투자증권', 'code': '005940'},
#  {'name': 'NI스틸', 'code': '008260'},
#  {'name': 'SK디앤디', 'code': '210980'},
#  {'name': 'SK증권', 'code': '001510'},
#  {'name': 'SK케미칼', 'code': '285130'},
#  {'name': 'SPC삼립', 'code': '005610'},
#  {'name': '강원랜드', 'code': '035250'},
#  {'name': '경인양행', 'code': '012610'},
#  {'name': '경인전자', 'code': '009140'},
#  {'name': '금비', 'code': '008870'},
#  {'name': '기신정기', 'code': '092440'},
#  {'name': '기업은행', 'code': '024110'},
#  {'name': '남선알미늄', 'code': '008350'},
#  {'name': '남양유업', 'code': '003920'},
#  {'name': '대교', 'code': '019680'},
#  {'name': '대동전자', 'code': '008110'},
#  {'name': '대림비앤코', 'code': '005750'},
#  {'name': '대성에너지', 'code': '117580'},
#  {'name': '대창', 'code': '012800'},
#  {'name': '대한제분', 'code': '001130'},
#  {'name': '대한해운', 'code': '005880'},
#  {'name': '덕양산업', 'code': '024900'},
#  {'name': '동국제강', 'code': '001230'},
#  {'name': '동일제강', 'code': '002690'},
#  {'name': '디아이씨', 'code': '092200'},
#  {'name': '디와이파워', 'code': '210540'},
#  {'name': '롯데관광개발', 'code': '032350'},
#  {'name': '롯데정밀화학', 'code': '004000'},
#  {'name': '롯데지주', 'code': '004990'},
#  {'name': '롯데푸드', 'code': '002270'},
#  {'name': '맵스리얼티1', 'code': '094800'},
#  {'name': '무림P&P', 'code': '009580'},
#  {'name': '미래아이앤지', 'code': '007120'},
#  {'name': '부산주공', 'code': '005030'},
#  {'name': '사조오양', 'code': '006090'},
#  {'name': '삼성물산', 'code': '028260'},
#  {'name': '삼성전자', 'code': '005930'},
#  {'name': '삼성제약', 'code': '001360'},
#  {'name': '삼익THK', 'code': '004380'},
#  {'name': '삼일제약', 'code': '000520'},
#  {'name': '삼화왕관', 'code': '004450'},
#  {'name': '서연', 'code': '007860'},
#  {'name': '성문전자', 'code': '014910'},
#  {'name': '세기상사', 'code': '002420'},
#  {'name': '세우글로벌', 'code': '013000'},
#  {'name': '세원정공', 'code': '021820'},
#  {'name': '셀트리온', 'code': '068270'},
#  {'name': '신라교역', 'code': '004970'},
#  {'name': '신성통상', 'code': '005390'},
#  {'name': '신송홀딩스', 'code': '006880'},
#  {'name': '씨에스윈드', 'code': '112610'},
#  {'name': '아모레퍼시픽', 'code': '090430'},
#  {'name': '아세아', 'code': '002030'},
#  {'name': '아세아제지', 'code': '002310'},
#  {'name': '알루코', 'code': '001780'},
#  {'name': '애경산업', 'code': '018250'},
#  {'name': '애경케미칼', 'code': '161000'},
#  {'name': '에스원', 'code': '012750'},
#  {'name': '에이블씨엔씨', 'code': '078520'},
#  {'name': '에이엔피', 'code': '015260'},
#  {'name': '영원무역홀딩스', 'code': '009970'},
#  {'name': '우신시스템', 'code': '017370'},
#  {'name': '우진플라임', 'code': '049800'},
#  {'name': '유니드', 'code': '014830'},
#  {'name': '유안타증권', 'code': '003470'},
#  {'name': '와이투솔루션', 'code': '011690'},
#  {'name': '이건산업', 'code': '008250'},
#  {'name': '조비', 'code': '001550'},
#  {'name': '조선내화', 'code': '000480'},
#  {'name': '참엔지니어링', 'code': '009310'},
#  {'name': '케이씨씨', 'code': '002380'},
#  {'name': '코오롱글로벌', 'code': '003070'},
#  {'name': '쿠쿠홈시스', 'code': '284740'},
#  {'name': '키움증권', 'code': '039490'},
#  {'name': '태영건설', 'code': '009410'},
#  {'name': '페이퍼코리아', 'code': '001020'},
#  {'name': '평화홀딩스', 'code': '010770'},
#  {'name': '포스코스틸리온', 'code': '058430'},
#  {'name': '한국전자홀딩스', 'code': '006200'},
#  {'name': '한국주강', 'code': '025890'},
#  {'name': '한국화장품제조', 'code': '003350'},
#  {'name': '한라', 'code': '014790'},
#  {'name': '한진중공업홀딩스', 'code': '003480'},
#  {'name': '한진칼', 'code': '180640'},
#  {'name': '한화', 'code': '000880'},
#  {'name': '한화생명', 'code': '088350'},
#  {'name': '현대엘리베이터', 'code': '017800'},
#  {'name': '효성중공업', 'code': '298040'},
#  {'name': 'BGF리테일', 'code': '282330'},
#  {'name': 'CJ씨푸드', 'code': '011150'},
#  {'name': 'CJ제일제당', 'code': '097950'},
#  {'name': 'DB금융투자', 'code': '016610'},
#  {'name': 'DGB금융지주', 'code': '139130'},
#  {'name': 'E1', 'code': '017940'},
#  {'name': 'GS', 'code': '078930'},
#  {'name': 'HDC현대EP', 'code': '089470'},
#  {'name': 'KEC', 'code': '092220'},
#  {'name': 'KISCO홀딩스', 'code': '001940'},
#  {'name': 'KPX홀딩스', 'code': '092230'},
#  {'name': 'SNT에너지', 'code': '100840'},
#  {'name': 'SNT중공업', 'code': '003570'},
#  {'name': 'SNT홀딩스', 'code': '036530'},
#  {'name': 'SK가스', 'code': '018670'},
#  {'name': 'SK디스커버리', 'code': '006120'},
#  {'name': 'SK이노베이션', 'code': '096770'},
#  {'name': 'TCC스틸', 'code': '002710'},
#  {'name': '계룡건설산업', 'code': '013580'},
#  {'name': '국보', 'code': '001140'},
#  {'name': '이엔플러스', 'code': '074610'},
#  {'name': '녹십자', 'code': '006280'},
#  {'name': '대덕', 'code': '008060'},
#  {'name': '대성산업', 'code': '128820'},
#  {'name': '더존비즈온', 'code': '012510'},
#  {'name': '동부건설', 'code': '005960'},
#  {'name': '동원F&B', 'code': '049770'},
#  {'name': '디아이동일', 'code': '001530'},
#  {'name': '두산밥캣', 'code': '241560'},
#  {'name': '만호제강', 'code': '001080'},
#  {'name': '메타랩스', 'code': '090370'},
#  {'name': '모나리자', 'code': '012690'},
#  {'name': '모나미', 'code': '005360'},
#  {'name': '문배철강', 'code': '008420'},
#  {'name': '미창석유공업', 'code': '003650'},
#  {'name': '바다로19호', 'code': '155900'},
#  {'name': '백광산업', 'code': '001340'},
#  {'name': '벽산', 'code': '007210'},
#  {'name': '부광약품', 'code': '003000'},
#  {'name': '부국증권', 'code': '001270'},
#  {'name': '비상교육', 'code': '100220'},
#  {'name': '삼성공조', 'code': '006660'},
#  {'name': '삼성생명', 'code': '032830'},
#  {'name': '삼성전기', 'code': '009150'},
#  {'name': '삼양홀딩스', 'code': '000070'},
#  {'name': '삼화전기', 'code': '009470'},
#  {'name': '샘표', 'code': '007540'},
#  {'name': '서흥', 'code': '008490'},
#  {'name': '세진중공업', 'code': '075580'},
#  {'name': '수산중공업', 'code': '017550'},
#  {'name': '신세계I&C', 'code': '035510'},
#  {'name': '신세계건설', 'code': '034300'},
#  {'name': '신원', 'code': '009270'},
#  {'name': '쌍용자동차', 'code': '003620'},
#  {'name': '에이프로젠 MED', 'code': '007460'},
#  {'name': '엔피씨', 'code': '004250'},
#  {'name': '우성', 'code': '006980'},
#  {'name': '웅진씽크빅', 'code': '095720'},
#  {'name': '웰바이오텍', 'code': '010600'},
#  {'name': '유유제약', 'code': '000220'},
#  {'name': '이아이디', 'code': '093230'},
#  {'name': '인천도시가스', 'code': '034590'},
#  {'name': '일동홀딩스', 'code': '000230'},
#  {'name': '일진머티리얼즈', 'code': '020150'},
#  {'name': '일진전기', 'code': '103590'},
#  {'name': '진양홀딩스', 'code': '100250'},
#  {'name': '센트럴인사이트', 'code': '012600'},
#  {'name': '카카오', 'code': '035720'},
#  {'name': '케이씨티시', 'code': '009070'},
#  {'name': '케이탑리츠', 'code': '145270'},
#  {'name': '케이티스카이라이프', 'code': '053210'},
#  {'name': '코리안리', 'code': '003690'},
#  {'name': '크라운해태홀딩스', 'code': '005740'},
#  {'name': '태원물산', 'code': '001420'},
#  {'name': '팬오션', 'code': '028670'},
#  {'name': '평화산업', 'code': '090080'},
#  {'name': '한국프랜지공업', 'code': '010100'},
#  {'name': '한미글로벌', 'code': '053690'},
#  {'name': '한샘', 'code': '009240'},
#  {'name': '한세엠케이', 'code': '069640'},
#  {'name': '한솔케미칼', 'code': '014680'},
#  {'name': '한일홀딩스', 'code': '003300'},
#  {'name': '한화솔루션', 'code': '009830'},
#  {'name': '현대일렉트릭', 'code': '267260'},
#  {'name': '현대제철', 'code': '004020'},
#  {'name': '형지엘리트', 'code': '093240'},
#  {'name': '혜인', 'code': '003010'},
#  {'name': '화신', 'code': '010690'},
#  {'name': '휴비스', 'code': '079980'},
#  {'name': 'DB', 'code': '012030'},
#  {'name': 'DB손해보험', 'code': '005830'},
#  {'name': 'F&F 홀딩스', 'code': '007700'},
#  {'name': 'GS리테일', 'code': '007070'},
#  {'name': 'JW생명과학', 'code': '234080'},
#  {'name': 'KC그린홀딩스', 'code': '009440'},
#  {'name': 'LG', 'code': '003550'},
#  {'name': 'LG유플러스', 'code': '032640'},
#  {'name': 'LG전자', 'code': '066570'},
#  {'name': 'LG화학', 'code': '051910'},
#  {'name': '엘에스일렉트릭', 'code': '010120'},
#  {'name': '경농', 'code': '002100'},
#  {'name': '고려아연', 'code': '010130'},
#  {'name': '광동제약', 'code': '009290'},
#  {'name': '교보증권', 'code': '030610'},
#  {'name': '국도화학', 'code': '007690'},
#  {'name': '금호타이어', 'code': '073240'},
#  {'name': '남해화학', 'code': '025860'},
#  {'name': '대원강업', 'code': '000430'},
#  {'name': '대원전선', 'code': '006340'},
#  {'name': '대원화성', 'code': '024890'},
#  {'name': '대한항공', 'code': '003490'},
#  {'name': 'KG스틸', 'code': '016380'},
#  {'name': '동성제약', 'code': '002210'},
#  {'name': '동양고속', 'code': '084670'},
#  {'name': '동양철관', 'code': '008970'},
#  {'name': '동원수산', 'code': '030720'},
#  {'name': '동일고무벨트', 'code': '163560'},
#  {'name': '두산에너빌리티', 'code': '034020'},
#  {'name': '롯데쇼핑', 'code': '023530'},
#  {'name': '만도', 'code': '204320'},
#  {'name': '메리츠화재', 'code': '000060'},
#  {'name': '태경비케이', 'code': '014580'},
#  {'name': '부국철강', 'code': '026940'},
#  {'name': '부산산업', 'code': '011390'},
#  {'name': 'SGC에너지', 'code': '005090'},
#  {'name': '삼성엔지니어링', 'code': '028050'},
#  {'name': '삼양패키징', 'code': '272550'},
#  {'name': '삼익악기', 'code': '002450'},
#  {'name': '삼천리', 'code': '004690'},
#  {'name': '서울식품공업', 'code': '004410'},
#  {'name': 'SUN&L', 'code': '002820'},
#  {'name': '성창기업지주', 'code': '000180'},
#  {'name': '세아베스틸지주', 'code': '001430'},
#  {'name': '세아제강지주', 'code': '003030'},
#  {'name': '세아홀딩스', 'code': '058650'},
#  {'name': '세하', 'code': '027970'},
#  {'name': '다이나믹디자인', 'code': '145210'},
#  {'name': '씨아이테크', 'code': '004920'},
#  {'name': '아세아시멘트', 'code': '183190'},
#  {'name': '인바이오젠', 'code': '101140'},
#  {'name': '에스엘', 'code': '005850'},
#  {'name': '엘브이엠씨', 'code': '900140'},
#  {'name': '오뚜기', 'code': '007310'},
#  {'name': '초록뱀헬스케어', 'code': '118000'},
#  {'name': '이구산업', 'code': '025820'},
#  {'name': '인터지스', 'code': '129260'},
#  {'name': '일진홀딩스', 'code': '015860'},
#  {'name': '자화전자', 'code': '033240'},
#  {'name': '전방', 'code': '000950'},
#  {'name': '제일기획', 'code': '030000'},
#  {'name': '조광피혁', 'code': '004700'},
#  {'name': '종근당홀딩스', 'code': '001630'},
#  {'name': '지엠비코리아', 'code': '013870'},
#  {'name': '에스엠벡셀', 'code': '010580'},
#  {'name': '지투알', 'code': '035000'},
#  {'name': '컨버즈', 'code': '109070'},
#  {'name': '코오롱인더', 'code': '120110'},
#  {'name': '태림포장', 'code': '011280'},
#  {'name': '티비에이치글로벌', 'code': '084870'},
#  {'name': '팜스코', 'code': '036580'},
#  {'name': '퍼스텍', 'code': '010820'},
#  {'name': '한국ANKOR유전', 'code': '152550'},
#  {'name': '한국내화', 'code': '010040'},
#  {'name': '한국단자공업', 'code': '025540'},
#  {'name': '한국앤컴퍼니', 'code': '000240'},
#  {'name': '한국특강', 'code': '007280'},
#  {'name': '한국화장품', 'code': '123690'},
#  {'name': '한미반도체', 'code': '042700'},
#  {'name': '한솔로지스틱스', 'code': '009180'},
#  {'name': '한솔제지', 'code': '213500'},
#  {'name': '한온시스템', 'code': '018880'},
#  {'name': '한올바이오파마', 'code': '009420'},
#  {'name': '해성디에스', 'code': '195870'},
#  {'name': '핸즈코퍼레이션', 'code': '143210'},
#  {'name': '현대건설', 'code': '000720'},
#  {'name': '현대리바트', 'code': '079430'},
#  {'name': '화성산업', 'code': '002460'},
#  {'name': '화천기계', 'code': '010660'},
#  {'name': '황금에스티', 'code': '032560'},
#  {'name': '효성첨단소재', 'code': '298050'},
#  {'name': '효성화학', 'code': '298000'},
#  {'name': '휴스틸', 'code': '005010'},
#  {'name': '티케이지휴켐스', 'code': '069260'},
#  {'name': 'AK홀딩스', 'code': '006840'},
#  {'name': 'BNK금융지주', 'code': '138930'},
#  {'name': 'DSR', 'code': '155660'},
#  {'name': 'HDC랩스', 'code': '039570'},
#  {'name': 'JB금융지주', 'code': '175330'},
#  {'name': 'KC코트렐', 'code': '119650'},
#  {'name': '다올투자증권', 'code': '030210'},
#  {'name': 'LX인터내셔널', 'code': '001120'},
#  {'name': 'LG생활건강', 'code': '051900'},
#  {'name': 'LS전선아시아', 'code': '229640'},
#  {'name': 'NICE', 'code': '034310'},
#  {'name': 'SG세계물산', 'code': '004060'},
#  {'name': 'SIMPAC', 'code': '009160'},
#  {'name': 'SK하이닉스', 'code': '000660'},
#  {'name': '가온전선', 'code': '000500'},
#  {'name': '계양전기', 'code': '012200'},
#  {'name': '고려산업', 'code': '002140'},
#  {'name': '금호건설', 'code': '002990'},
#  {'name': '금호석유화학', 'code': '011780'},
#  {'name': '넥센', 'code': '005720'},
#  {'name': '농심', 'code': '004370'},
#  {'name': '다우기술', 'code': '023590'},
#  {'name': '대동', 'code': '000490'},
#  {'name': '대우조선해양', 'code': '042660'},
#  {'name': '대한화섬', 'code': '003830'},
#  {'name': '대호에이엘', 'code': '069460'},
#  {'name': '덴티움', 'code': '145720'},
#  {'name': '동아타이어', 'code': '282690'},
#  {'name': '동양피스톤', 'code': '092780'},
#  {'name': '동원시스템즈', 'code': '014820'},
#  {'name': '동화약품', 'code': '000020'},
#  {'name': '두산', 'code': '000150'},
#  {'name': '디와이', 'code': '013570'},
#  {'name': '롯데제과', 'code': '280360'},
#  {'name': '미래산업', 'code': '025560'},
#  {'name': '방림', 'code': '003610'},
#  {'name': '삼아알미늄', 'code': '006110'},
#  {'name': '삼화콘덴서공업', 'code': '001820'},
#  {'name': '새론오토모티브', 'code': '075180'},
#  {'name': '세방', 'code': '004360'},
#  {'name': '세아특수강', 'code': '019440'},
#  {'name': '세종공업', 'code': '033530'},
#  {'name': '신도리코', 'code': '029530'},
#  {'name': '신세계', 'code': '004170'},
#  {'name': '신세계인터내셔날', 'code': '031430'},
#  {'name': '신세계푸드', 'code': '031440'},
#  {'name': '쌍용씨앤이', 'code': '003410'},
#  {'name': '아남전자', 'code': '008700'},
#  {'name': '에쓰씨엔지니어링', 'code': '023960'},
#  {'name': '에이리츠', 'code': '140910'},
#  {'name': '플레이그램', 'code': '009810'},
#  {'name': '오리엔트바이오', 'code': '002630'},
#  {'name': '오리온홀딩스', 'code': '001800'},
#  {'name': '팜젠사이언스', 'code': '004720'},
#  {'name': '유니퀘스트', 'code': '077500'},
#  {'name': '유수홀딩스', 'code': '000700'},
#  {'name': '이수페타시스', 'code': '007660'},
#  {'name': '이연제약', 'code': '102460'},
#  {'name': '일신석재', 'code': '007110'},
#  {'name': '일양약품', 'code': '007570'},
#  {'name': '일진다이아', 'code': '081000'},
#  {'name': '조광페인트', 'code': '004910'},
#  {'name': '주연테크', 'code': '044380'},
#  {'name': '진양산업', 'code': '003780'},
#  {'name': '케이씨텍', 'code': '281820'},
#  {'name': 'KTis', 'code': '058860'},
#  {'name': '풀무원', 'code': '017810'},
#  {'name': '하이트진로홀딩스', 'code': '000140'},
#  {'name': '한국쉘석유', 'code': '002960'},
#  {'name': '한국콜마홀딩스', 'code': '024720'},
#  {'name': '한국타이어앤테크놀로지', 'code': '161390'},
#  {'name': '한농화성', 'code': '011500'},
#  {'name': '한미사이언스', 'code': '008930'},
#  {'name': '한세실업', 'code': '105630'},
#  {'name': '한세예스24홀딩스', 'code': '016450'},
#  {'name': '한신공영', 'code': '004960'},
#  {'name': '한양증권', 'code': '001750'},
#  {'name': '한익스프레스', 'code': '014130'},
#  {'name': '한전기술', 'code': '052690'},
#  {'name': '한화손해보험', 'code': '000370'},
#  {'name': '한화투자증권', 'code': '003530'},
#  {'name': '현대글로비스', 'code': '086280'},
#  {'name': '현대백화점', 'code': '069960'},
#  {'name': '현대위아', 'code': '011210'},
#  {'name': '현대자동차', 'code': '005380'},
#  {'name': '현대차증권', 'code': '001500'},
#  {'name': '현대코퍼레이션홀딩스', 'code': '227840'},
#  {'name': '현대홈쇼핑', 'code': '057050'},
#  {'name': '화승코퍼레이션', 'code': '013520'},
#  {'name': '화인베스틸', 'code': '133820'},
#  {'name': '흥아해운', 'code': '003280'},
#  {'name': 'BYC', 'code': '001460'},
#  {'name': 'KTcs', 'code': '058850'},
#  {'name': 'STX', 'code': '011810'},
#  {'name': 'STX엔진', 'code': '077970'},
#  {'name': '강남제비스코', 'code': '000860'},
#  {'name': '경동나비엔', 'code': '009450'},
#  {'name': '광명전기', 'code': '017040'},
#  {'name': '광전자', 'code': '017900'},
#  {'name': '광주신세계', 'code': '037710'},
#  {'name': '그린케미칼', 'code': '083420'},
#  {'name': '금호전기', 'code': '001210'},
#  {'name': '노루홀딩스', 'code': '000320'},
#  {'name': 'DL', 'code': '000210'},
#  {'name': '대상', 'code': '001680'},
#  {'name': '대성홀딩스', 'code': '016710'},
#  {'name': '대신증권', 'code': '003540'},
#  {'name': '대우부품', 'code': '009320'},
#  {'name': '대창단조', 'code': '015230'},
#  {'name': '대한제당', 'code': '001790'},
#  {'name': '도화엔지니어링', 'code': '002150'},
#  {'name': '동아에스티', 'code': '170900'},
#  {'name': '비케이탑스', 'code': '030790'},
#  {'name': 'TYM', 'code': '002900'},
#  {'name': 'HLB글로벌', 'code': '003580'},
#  {'name': '동일산업', 'code': '004890'},
#  {'name': '락앤락', 'code': '115390'},
#  {'name': '롯데칠성음료', 'code': '005300'},
#  {'name': '쎌마테라퓨틱스', 'code': '015540'},
#  {'name': '메리츠금융지주', 'code': '138040'},
#  {'name': '미래에셋증권', 'code': '006800'},
#  {'name': '미원상사', 'code': '002840'},
#  {'name': '사조산업', 'code': '007160'},
#  {'name': '삼부토건', 'code': '001470'},
#  {'name': '삼화전자공업', 'code': '011230'},
#  {'name': '상신브레이크', 'code': '041650'},
#  {'name': '서연이화', 'code': '200880'},
#  {'name': '서울도시가스', 'code': '017390'},
#  {'name': '성신양회', 'code': '004980'},
#  {'name': '성안', 'code': '011300'},
#  {'name': '신대양제지', 'code': '016590'},
#  {'name': '신일전자', 'code': '002700'},
#  {'name': '신풍제지', 'code': '002870'},
#  {'name': '신흥', 'code': '004080'},
#  {'name': '에넥스', 'code': '011090'},
#  {'name': '에스제이엠', 'code': '123700'},
#  {'name': '에스제이엠홀딩스', 'code': '025530'},
#  {'name': '에이프로젠제약', 'code': '003060'},
#  {'name': '영풍제지', 'code': '006740'},
#  {'name': '영흥', 'code': '012160'},
#  {'name': '용평리조트', 'code': '070960'},
#  {'name': '우리종금', 'code': '010050'},
#  {'name': '유성기업', 'code': '002920'},
#  {'name': '유엔젤', 'code': '072130'},
#  {'name': '율촌화학', 'code': '008730'},
#  {'name': '이노션', 'code': '214320'},
#  {'name': '이마트', 'code': '139480'},
#  {'name': '이화산업', 'code': '000760'},
#  {'name': '인스코비', 'code': '006490'},
#  {'name': '인팩', 'code': '023810'},
#  {'name': '일성건설', 'code': '013360'},
#  {'name': '일성신약', 'code': '003120'},
#  {'name': '일신방직', 'code': '003200'},
#  {'name': '잇츠한불', 'code': '226320'},
#  {'name': '제주은행', 'code': '006220'},
#  {'name': '제주항공', 'code': '089590'},
#  {'name': '천일고속', 'code': '000650'},
#  {'name': '체시스', 'code': '033250'},
#  {'name': '카프로', 'code': '006380'},
#  {'name': '케이티앤지', 'code': '033780'},
#  {'name': '쿠쿠홀딩스', 'code': '192400'},
#  {'name': '크라운제과', 'code': '264900'},
#  {'name': '아센디오', 'code': '012170'},
#  {'name': '태경산업', 'code': '015890'},
#  {'name': '테이팩스', 'code': '055490'},
#  {'name': '티에이치엔', 'code': '019180'},
#  {'name': 'POSCO홀딩스', 'code': '005490'},
#  {'name': '포스코인터내셔널', 'code': '047050'},
#  {'name': '풍산', 'code': '103140'},
#  {'name': 'KH 필룩스', 'code': '033180'},
#  {'name': '하나금융지주', 'code': '086790'},
#  {'name': '하나투어', 'code': '039130'},
#  {'name': '한국전력공사', 'code': '015760'},
#  {'name': '한국종합기술', 'code': '023350'},
#  {'name': '한성기업', 'code': '003680'},
#  {'name': '한솔피엔에스', 'code': '010420'},
#  {'name': '한솔홈데코', 'code': '025750'},
#  {'name': '한전산업', 'code': '130660'},
#  {'name': '한창', 'code': '005110'},
#  {'name': '현대로템', 'code': '064350'},
#  {'name': '현대모비스', 'code': '012330'},
#  {'name': '현대미포조선', 'code': '010620'},
#  {'name': '현대약품', 'code': '004310'},
#  {'name': '현대코퍼레이션', 'code': '011760'},
#  {'name': 'HD현대', 'code': '267250'},
#  {'name': '효성', 'code': '004800'},
#  {'name': '휠라홀딩스', 'code': '081660'},
#  {'name': '흥국화재', 'code': '000540'},
#  {'name': '신한알파리츠', 'code': '293940'},
#  {'name': '한일시멘트', 'code': '300720'},
#  {'name': '롯데정보통신', 'code': '286940'},
#  {'name': '티웨이항공', 'code': '091810'},
#  {'name': '우진아이엔에스', 'code': '010400'},
#  {'name': '하나제약', 'code': '293480'},
#  {'name': '세아제강', 'code': '306200'},
#  {'name': '아시아나IDT', 'code': '267850'},
#  {'name': 'CJ', 'code': '001040'},
#  {'name': '에어부산', 'code': '298690'},
#  {'name': '우리금융지주', 'code': '316140'},
#  {'name': 'CJ프레시웨이', 'code': '051500'},
#  {'name': 'EG', 'code': '037370'},
#  {'name': 'GH신소재', 'code': '130500'},
#  {'name': 'GST', 'code': '083450'},
#  {'name': 'KB오토시스', 'code': '024120'},
#  {'name': '이엠앤아이', 'code': '083470'},
#  {'name': 'NHN한국사이버결제', 'code': '060250'},
#  {'name': 'TJ미디어', 'code': '032540'},
#  {'name': 'UCI', 'code': '038340'},
#  {'name': 'YW', 'code': '051390'},
#  {'name': '갤럭시아머니트리', 'code': '094480'},
#  {'name': '컴투스홀딩스', 'code': '063080'},
#  {'name': '골드퍼시픽', 'code': '038530'},
#  {'name': '원바이오젠', 'code': '307280'},
#  {'name': '금화피에스시', 'code': '036190'},
#  {'name': '나스미디어', 'code': '089600'},
#  {'name': '네오티스', 'code': '085910'},
#  {'name': '녹십자엠에스', 'code': '142280'},
#  {'name': '뉴인텍', 'code': '012340'},
#  {'name': '뉴프렉스', 'code': '085670'},
#  {'name': '대명소노시즌', 'code': '007720'},
#  {'name': '대봉엘에스', 'code': '078140'},
#  {'name': '위니아', 'code': '071460'},
#  {'name': '대한광통신', 'code': '010170'},
#  {'name': '대한약품', 'code': '023910'},
#  {'name': '덕산네오룩스', 'code': '213420'},
#  {'name': '동방선기', 'code': '099410'},
#  {'name': '디에이피', 'code': '066900'},
#  {'name': '디엔에프', 'code': '092070'},
#  {'name': '디오', 'code': '039840'},
#  {'name': '디지틀조선', 'code': '033130'},
#  {'name': '디케이앤디', 'code': '263020'},
#  {'name': '디케이티', 'code': '290550'},
#  {'name': '레드캡투어', 'code': '038390'},
#  {'name': '리더스코스메틱', 'code': '016100'},
#  {'name': '마크로젠', 'code': '038290'},
#  {'name': '매직마이크로', 'code': '127160'},
#  {'name': '명성티엔에스', 'code': '257370'},
#  {'name': '모비스', 'code': '250060'},
#  {'name': '미래컴퍼니', 'code': '049950'},
#  {'name': '바디텍메드', 'code': '206640'},
#  {'name': '헬릭스미스', 'code': '084990'},
#  {'name': '바이오솔루션', 'code': '086820'},
#  {'name': '부스타', 'code': '008470'},
#  {'name': '비즈니스온', 'code': '138580'},
#  {'name': '삼기', 'code': '122350'},
#  {'name': '삼목에스폼', 'code': '018310'},
#  {'name': '삼보판지', 'code': '023600'},
#  {'name': '삼아제약', 'code': '009300'},
#  {'name': '세보엠이씨', 'code': '011560'},
#  {'name': '세종메디칼', 'code': '258830'},
#  {'name': '셀트리온헬스케어', 'code': '091990'},
#  {'name': '손오공', 'code': '066910'},
#  {'name': '스카이문스테크놀로지', 'code': '033790'},
#  {'name': '승일', 'code': '049830'},
#  {'name': '싸이토젠', 'code': '217330'},
#  {'name': '썸에이지', 'code': '208640'},
#  {'name': '에디슨EV', 'code': '136510'},
#  {'name': '클라우드에어', 'code': '036170'},
#  {'name': '아이씨디', 'code': '040910'},
#  {'name': '아이즈비전', 'code': '031310'},
#  {'name': '아이텍', 'code': '119830'},
#  {'name': '알에프세미', 'code': '096610'},
#  {'name': '알테오젠', 'code': '196170'},
#  {'name': '알티캐스트', 'code': '085810'},
#  {'name': '액션스퀘어', 'code': '205500'},
#  {'name': '이브이첨단소재', 'code': '131400'},
#  {'name': '에스디시스템', 'code': '121890'},
#  {'name': '이큐셀', 'code': '160600'},
#  {'name': '휴엠앤씨', 'code': '263920'},
#  {'name': '에스코넥', 'code': '096630'},
#  {'name': '에스티아이', 'code': '039440'},
#  {'name': '에스티오', 'code': '098660'},
#  {'name': '에이치엔티', 'code': '176440'},
#  {'name': '에이티넘인베스트', 'code': '021080'},
#  {'name': '에이티세미콘', 'code': '089530'},
#  {'name': '에이피티씨', 'code': '089970'},
#  {'name': '유네코', 'code': '064510'},
#  {'name': '에코마케팅', 'code': '230360'},
#  {'name': '에프에스티', 'code': '036810'},
#  {'name': '엑셈', 'code': '205100'},
#  {'name': '엘비세미콘', 'code': '061970'},
#  {'name': '엘아이에스', 'code': '138690'},
#  {'name': '연이비앤티', 'code': '090740'},
#  {'name': '오공', 'code': '045060'},
#  {'name': '오스템임플란트', 'code': '048260'},
#  {'name': '오이솔루션', 'code': '138080'},
#  {'name': '오픈베이스', 'code': '049480'},
#  {'name': '와이지-원', 'code': '019210'},
#  {'name': '원익QnC', 'code': '074600'},
#  {'name': '원익큐브', 'code': '014190'},
#  {'name': '원풍물산', 'code': '008290'},
#  {'name': '웨이브일렉트로', 'code': '095270'},
#  {'name': '웰크론', 'code': '065950'},
#  {'name': '위지트', 'code': '036090'},
#  {'name': '육일씨엔에쓰', 'code': '191410'},
#  {'name': '이노인스트루먼트', 'code': '215790'},
#  {'name': '이상네트웍스', 'code': '080010'},
#  {'name': '이스트소프트', 'code': '047560'},
#  {'name': '이엔에프테크놀로지', 'code': '102710'},
#  {'name': '이트론', 'code': '096040'},
#  {'name': '잉크테크', 'code': '049550'},
#  {'name': '제우스', 'code': '079370'},
#  {'name': '제이엔케이히터', 'code': '126880'},
#  {'name': '제주반도체', 'code': '080220'},
#  {'name': '조아제약', 'code': '034940'},
#  {'name': '좋은사람들', 'code': '033340'},
#  {'name': '주성엔지니어링', 'code': '036930'},
#  {'name': '지엔코', 'code': '065060'},
#  {'name': '진매트릭스', 'code': '109820'},
#  {'name': '창해에탄올', 'code': '004650'},
#  {'name': '케이피엠테크', 'code': '042040'},
#  {'name': '케이피티유', 'code': '054410'},
#  {'name': '켐트로스', 'code': '220260'},
#  {'name': '코스온', 'code': '069110'},
#  {'name': '코아스템', 'code': '166480'},
#  {'name': '코웰패션', 'code': '033290'},
#  {'name': '코이즈', 'code': '121850'},
#  {'name': '코프라', 'code': '126600'},
#  {'name': '크로바하이텍', 'code': '043590'},
#  {'name': '토탈소프트', 'code': '045340'},
#  {'name': '톱텍', 'code': '108230'},
#  {'name': '트루윈', 'code': '105550'},
#  {'name': '특수건설', 'code': '026150'},
#  {'name': '파세코', 'code': '037070'},
#  {'name': '파수', 'code': '150900'},
#  {'name': '판타지오', 'code': '032800'},
#  {'name': 'CNT85', 'code': '056730'},
#  {'name': '푸드웰', 'code': '005670'},
#  {'name': '푸른저축은행', 'code': '007330'},
#  {'name': '프로스테믹스', 'code': '203690'},
#  {'name': '피에스엠씨', 'code': '024850'},
#  {'name': '지엔원에너지', 'code': '270520'},
#  {'name': '하나마이크론', 'code': '067310'},
#  {'name': '에이팩트', 'code': '200470'},
#  {'name': '한국맥널티', 'code': '222980'},
#  {'name': '한국전자금융', 'code': '063570'},
#  {'name': '한국전자인증', 'code': '041460'},
#  {'name': '한양디지텍', 'code': '078350'},
#  {'name': '한일화학', 'code': '007770'},
#  {'name': '한컴MDS', 'code': '086960'},
#  {'name': '해성옵틱스', 'code': '076610'},
#  {'name': '헝셩그룹', 'code': '900270'},
#  {'name': '화성밸브', 'code': '039610'},
#  {'name': '스튜디오산타클로스', 'code': '204630'},
#  {'name': '휴메딕스', 'code': '200670'},
#  {'name': 'APS홀딩스', 'code': '054620'},
#  {'name': 'CMG제약', 'code': '058820'},
#  {'name': 'CS', 'code': '065770'},
#  {'name': '케스피온', 'code': '079190'},
#  {'name': 'HRS', 'code': '036640'},
#  {'name': '알로이스', 'code': '297570'},
#  {'name': 'KMH', 'code': '122450'},
#  {'name': 'KPX생명과학', 'code': '114450'},
#  {'name': 'PN풍년', 'code': '024940'},
#  {'name': 'SBI핀테크솔루션즈', 'code': '950110'},
#  {'name': 'SGA솔루션즈', 'code': '184230'},
#  {'name': 'SM Life Design', 'code': '063440'},
#  {'name': 'SV인베스트먼트', 'code': '289080'},
#  {'name': 'KBI메탈', 'code': '024840'},
#  {'name': '골든센츄리', 'code': '900280'},
#  {'name': '광림', 'code': '014200'},
#  {'name': '광진실업', 'code': '026910'},
#  {'name': '국순당', 'code': '043650'},
#  {'name': '국영지앤엠', 'code': '006050'},
#  {'name': '국일신동', 'code': '060480'},
#  {'name': '나노', 'code': '187790'},
#  {'name': '나노엔텍', 'code': '039860'},
#  {'name': '나우IB', 'code': '293580'},
#  {'name': '내츄럴엔도텍', 'code': '168330'},
#  {'name': '넥스턴바이오', 'code': '089140'},
#  {'name': '뉴로스', 'code': '126870'},
#  {'name': '뉴파워프라즈마', 'code': '144960'},
#  {'name': '애머릿지', 'code': '900100'},
#  {'name': '대동금속', 'code': '020400'},
#  {'name': '대아티아이', 'code': '045390'},
#  {'name': '대유에이피', 'code': '290120'},
#  {'name': '대주전자재료', 'code': '078600'},
#  {'name': '대창솔루션', 'code': '096350'},
#  {'name': '덕우전자', 'code': '263600'},
#  {'name': '데이타솔루션', 'code': '263800'},
#  {'name': '레이크머티리얼즈', 'code': '281740'},
#  {'name': '동아엘텍', 'code': '088130'},
#  {'name': '디아이티', 'code': '110990'},
#  {'name': '디알텍', 'code': '214680'},
#  {'name': '에이치앤비디자인', 'code': '227100'},
#  {'name': 'ES큐브', 'code': '050120'},
#  {'name': '러셀', 'code': '217500'},
#  {'name': '얼라인드', 'code': '238120'},
#  {'name': '로체시스템즈', 'code': '071280'},
#  {'name': '매일유업', 'code': '267980'},
#  {'name': '메디아나', 'code': '041920'},
#  {'name': '메타바이오메드', 'code': '059210'},
#  {'name': '모두투어', 'code': '080160'},
#  {'name': '모아텍', 'code': '033200'},
#  {'name': '모트렉스', 'code': '118990'},
#  {'name': '미코', 'code': '059090'},
#  {'name': '미투온', 'code': '201490'},
#  {'name': '베셀', 'code': '177350'},
#  {'name': '보라티알', 'code': '250000'},
#  {'name': '이엔코퍼레이션', 'code': '066980'},
#  {'name': '브이원텍', 'code': '251630'},
#  {'name': '블루콤', 'code': '033560'},
#  {'name': '비아트론', 'code': '141000'},
#  {'name': '비츠로셀', 'code': '082920'},
#  {'name': '비트컴퓨터', 'code': '032850'},
#  {'name': '빛샘전자', 'code': '072950'},
#  {'name': '삼륭물산', 'code': '014970'},
#  {'name': '삼양옵틱스', 'code': '225190'},
#  {'name': '삼일', 'code': '032280'},
#  {'name': '삼일기업공사', 'code': '002290'},
#  {'name': '삼지전자', 'code': '037460'},
#  {'name': '삼진', 'code': '032750'},
#  {'name': '삼표시멘트', 'code': '038500'},
#  {'name': '삼화네트웍스', 'code': '046390'},
#  {'name': '상신이디피', 'code': '091580'},
#  {'name': '상아프론테크', 'code': '089980'},
#  {'name': '서린바이오', 'code': '038070'},
#  {'name': '서울제약', 'code': '018680'},
#  {'name': '서전기전', 'code': '189860'},
#  {'name': '서진시스템', 'code': '178320'},
#  {'name': '성우하이텍', 'code': '015750'},
#  {'name': '세명전기', 'code': '017510'},
#  {'name': '에스엘바이오닉스', 'code': '214310'},
#  {'name': '파나케이아', 'code': '058530'},
#  {'name': '스타플렉스', 'code': '115570'},
#  {'name': '스페코', 'code': '013810'},
#  {'name': '신라에스지', 'code': '025870'},
#  {'name': '심텍홀딩스', 'code': '036710'},
#  {'name': '씨씨에스', 'code': '066790'},
#  {'name': '씨큐브', 'code': '101240'},
#  {'name': 'HLB제약', 'code': '047920'},
#  {'name': '아가방컴퍼니', 'code': '013990'},
#  {'name': '아모텍', 'code': '052710'},
#  {'name': '아미코젠', 'code': '092040'},
#  {'name': '아이에이', 'code': '038880'},
#  {'name': '안트로젠', 'code': '065660'},
#  {'name': '앱클론', 'code': '174900'},
#  ...]

# %%
df
# Out:
#           code      date    close     high      low     open   volume
# 0       082740  20220531   8730.0   8840.0   8520.0   8520.0   387301
# 1       082740  20220530   8510.0   8640.0   8380.0   8630.0   373313
# 2       082740  20220527   8450.0   8510.0   8240.0   8410.0   446609
# 3       082740  20220526   8390.0   8560.0   8220.0   8290.0   489793
# 4       082740  20220525   8260.0   8310.0   7990.0   8090.0   609532
# ...        ...       ...      ...      ...      ...      ...      ...
# 322475  389030  20211115  12650.0  12950.0  12350.0  12600.0   272215
# 322476  389030  20211112  12650.0  13500.0  12250.0  12350.0   554986
# 322477  389030  20211111  12350.0  12900.0  12100.0  12100.0   450149
# 322478  389030  20211110  12150.0  12750.0  12100.0  12700.0   441404
# 322479  389030  20211109  12800.0  13700.0  12250.0  13350.0  1156403
#
# [322480 rows x 7 columns]

# %%
X = []
names = []
w = 20
n = 120+w-1

for code_item in tqdm(codes):
    code = code_item['code']
    _df = df[df['code'] == code].dropna()

    if len(_df) < n:
        continue

    _df = _df.sort_values(by='date', ascending=True)
    _df['x'] = _df['close'] / _df.iloc[0]['close'] - 1
    _df = _df.dropna()

    if len(_df) < n:
        continue

    _df['x'] = pd.Series(_df['x']).rolling(w).mean()
    X.append(_df['x'].tolist()[w-1:])
    names.append(code_item['name'])

X = np.array(X)
names = np.array(names)
# Out:
# 100%|██████████| 2375/2375 [00:52<00:00, 45.37it/s]

# %%
X
# Out:
# array([[-0.08, -0.08, -0.08, ...,  0.11,  0.09,  0.08],
#        [-0.09, -0.1 , -0.1 , ...,  0.01, -0.  , -0.01],
#        [ 0.29,  0.31,  0.32, ...,  0.63,  0.64,  0.65],
#        ...,
#        [-0.03, -0.04, -0.04, ...,  0.08,  0.08,  0.08],
#        [ 0.26,  0.27,  0.29, ..., -0.34, -0.35, -0.35],
#        [ 0.02,  0.02,  0.03, ..., -0.2 , -0.2 , -0.2 ]])

# %%
k = 30
model = KMeans(n_clusters=k, random_state=42)
model.fit(Normalizer().fit_transform(X))

from collections import Counter
print(Counter(model.labels_))
# Out:
# Counter({23: 309, 12: 194, 25: 193, 5: 134, 22: 124, 1: 114, 18: 112, 0: 100, 24: 81, 4: 79, 10: 77, 2: 72, 21: 69, 29: 67, 3: 60, 16: 54, 28: 54, 7: 50, 8: 44, 14: 42, 6: 41, 11: 40, 20: 37, 17: 35, 26: 30, 13: 29, 27: 21, 19: 21, 15: 19, 9: 18})

# %%
model.n_clusters
# Out:
# 30

# %%
import matplotlib.font_manager as fm
import matplotlib
from scipy.spatial.distance import euclidean

font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = 'Malgun Gothic'
fm.FontProperties(fname=font_path).get_name()
matplotlib.rc('font', family=font_name)
matplotlib.rc('axes', unicode_minus=False)

def plot_clusters(model, k):
    # %matplotlib inline
    c = 5
    fig, axes = plt.subplots(nrows=k, ncols=c+1, figsize=(c*3, k*2))

    for label in range(k):
        x = model.cluster_centers_[label]
        axes[label][0].plot(np.arange(len(x)), x)
        axes[label][0].set_title(f'Cluster_{label}: Trend')
        axes[label][0].set_ylim([min(x.min()-0.01, 0.1), max(x.max()+0.01, 0.1)])
        n = 0
        _X = X[model.labels_ == label]
        _names = names[model.labels_ == label]
        dist = [euclidean(x, _x) for _x in _X]
        idxs = np.argsort(dist)[:c]

        for x, name in zip(_X[idxs], _names[idxs]):
            n += 1
            axes[label][n].plot(np.arange(len(x)), x)
            axes[label][n].set_title(f'{label}: {name}')
            axes[label][n].set_ylim([min(x.min()-0.01, 0.1), max(x.max()+0.01, 0.1)])
            if n >= c:
                break

    plt.tight_layout()
    plt.show()

plot_clusters(model, k)

# %%
names[model.labels_ == 1]
# Out:
# array(['SK네트웍스', '대웅', '롯데하이마트', '미래에셋생명', '삼성출판사', '한국조선해양', 'SKC',
#        '동양생명', '세방전지', '종근당', '한독', '한일현대시멘트', 'YG PLUS', '비비안', '유진증권',
#        '유화증권', '종근당바이오', '텔코웨어', '한국자산신탁', '삼성물산', '세기상사', '셀트리온',
#        '씨에스윈드', '평화홀딩스', '포스코스틸리온', '한화', 'DB금융투자', 'KPX홀딩스', '디아이동일',
#        '부광약품', '신세계I&C', '카카오', '국도화학', '세아베스틸지주', '인바이오젠', '한올바이오파마',
#        '효성첨단소재', '다우기술', '동화약품', '일양약품', '한국쉘석유', '한익스프레스', 'KTcs',
#        '노루홀딩스', '대신증권', '동아에스티', '인스코비', '일성건설', '효성', '나스미디어', '디오',
#        '알테오젠', '위지트', '휴메딕스', '옵티시스', '에이비프로바이오', '정상제이엘에스', '포스코케미칼',
#        'SBS콘텐츠허브', '초록뱀컴퍼니', '디지털대성', '메디톡스', '쎌바이오텍', '아이오케이', '포스코 ICT',
#        '한국경제TV', '신원종합개발', '지니뮤직', '초록뱀미디어', '코엔텍', '경동제약', '아즈텍WB',
#        '앤디포스', '예스24', '이엠코리아', '파이오링크', '펩트론', '하이텍팜', '한국큐빅', '선익시스템',
#        '위지윅스튜디오', 'iMBC', '대정화금', '동양이엔피', '디알젬', '에스트래픽', '이크레더블', '멜파스',
#        '신일제약', '유비케어', '제룡산업', '차바이오텍', '코콤', '아이스크림에듀', '솔루스첨단소재',
#        '씨에스베어링', '라파스', '녹십자웰빙', '에스케이바이오팜', '미투젠', '비비씨', '비나텍',
#        '씨엔알리서치', '미코바이오메드', '위드텍', '하이딥', '석경에이티', '프레스티지바이오파마', '에이치피오',
#        '맥스트', '애드바이오텍', '래몽래인', '리파인', '지니너스'], dtype='<U14')
