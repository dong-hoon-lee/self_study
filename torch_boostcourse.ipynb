# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
x = torch.FloatTensor([[0, 0], [0, 1], [1, 0], [1, 1]]).to(device)
y = torch.FloatTensor([[0], [1], [1], [0]]).to(device)

# nn layer
linear = nn.Linear(2, 1, bias=True)
sigmoid = nn.Sigmoid()
model = nn.Sequential(linear, sigmoid).to(device)   # sequential 역할: 모듈을 연결하는 역할

# define loss, optimizer
criterion = torch.nn.BCELoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01)

for step in range(10001):
    optimizer.zero_grad()
    hypothesis = model(x)   # 예측값

    # loss function
    loss = criterion(hypothesis, y)     # loss 계산
    loss.backward()
    optimizer.step()

    if step % 100 == 0:
        print(step, loss.item())
# Out:
# 0 0.7076359391212463
# 100 0.7050924897193909
# 200 0.703458845615387
# 300 0.7022885680198669
# 400 0.7013696432113647
# 500 0.7006006240844727
# 600 0.6999313235282898
# 700 0.6993362307548523
# 800 0.6988006830215454
# 900 0.6983158588409424
# 1000 0.6978752613067627
# 1100 0.6974742412567139
# 1200 0.697108805179596
# 1300 0.6967755556106567
# 1400 0.6964713931083679
# 1500 0.6961938142776489
# 1600 0.6959402561187744
# 1700 0.6957085132598877
# 1800 0.6954967975616455
# 1900 0.6953030824661255
# 2000 0.695125937461853
# 2100 0.694963812828064
# 2200 0.6948153972625732
# 2300 0.6946796178817749
# 2400 0.6945551037788391
# 2500 0.6944410800933838
# 2600 0.6943365931510925
# 2700 0.6942406892776489
# 2800 0.6941527724266052
# 2900 0.6940722465515137
# 3000 0.6939982175827026
# 3100 0.6939302682876587
# 3200 0.6938679218292236
# 3300 0.6938105821609497
# 3400 0.6937580704689026
# 3500 0.6937096118927002
# 3600 0.6936651468276978
# 3700 0.6936243772506714
# 3800 0.6935867071151733
# 3900 0.6935523152351379
# 4000 0.6935204267501831
# 4100 0.6934912204742432
# 4200 0.6934643387794495
# 4300 0.6934395432472229
# 4400 0.6934167146682739
# 4500 0.693395733833313
# 4600 0.6933764219284058
# 4700 0.6933586597442627
# 4800 0.6933422088623047
# 4900 0.6933270692825317
# 5000 0.6933131217956543
# 5100 0.6933003067970276
# 5200 0.6932884454727173
# 5300 0.6932775974273682
# 5400 0.6932674646377563
# 5500 0.6932582855224609
# 5600 0.6932497024536133
# 5700 0.6932418942451477
# 5800 0.6932346224784851
# 5900 0.6932278275489807
# 6000 0.6932216882705688
# 6100 0.6932159066200256
# 6200 0.6932106614112854
# 6300 0.6932058930397034
# 6400 0.6932013630867004
# 6500 0.6931972503662109
# 6600 0.6931933760643005
# 6700 0.6931898593902588
# 6800 0.6931865215301514
# 6900 0.6931836009025574
# 7000 0.6931807994842529
# 7100 0.6931781768798828
# 7200 0.6931758522987366
# 7300 0.6931736469268799
# 7400 0.6931717395782471
# 7500 0.6931698322296143
# 7600 0.6931681036949158
# 7700 0.6931665539741516
# 7800 0.6931650638580322
# 7900 0.6931636333465576
# 8000 0.6931623220443726
# 8100 0.6931613087654114
# 8200 0.6931601762771606
# 8300 0.6931591629981995
# 8400 0.6931583881378174
# 8500 0.693157434463501
# 8600 0.6931567192077637
# 8700 0.6931558847427368
# 8800 0.6931553483009338
# 8900 0.6931545734405518
# 9000 0.6931540966033936
# 9100 0.6931535601615906
# 9200 0.6931530833244324
# 9300 0.693152666091919
# 9400 0.6931522488594055
# 9500 0.6931518912315369
# 9600 0.6931514739990234
# 9700 0.6931511759757996
# 9800 0.6931508779525757
# 9900 0.6931505799293518
# 10000 0.6931503415107727

# %%
hypothesis
# Out:
# tensor([[0.4980],
#         [0.4998],
#         [0.4996],
#         [0.5014]], grad_fn=<SigmoidBackward0>)

# %%
y
# Out:
# tensor([[0.],
#         [1.],
#         [1.],
#         [0.]])
